# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Telecom Customer Churn Modelling</h1>
#     <h4 align="center" >Alireza Esmaeilpour</h4>
#     <h6 align="center"><a href="https://alireza-esp.ir/">Website</a></h6>
#     <h6 align="center"><a href="https://github.com/Alireza-Esp">Github</a></h6>
#     <h6 align="center"><a href="https://www.kaggle.com/alirezaesmaeilpour">Kaggle</a></h6>
# </div>

# %% [markdown]
# # 🔵 Import Libraries

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 🔵 Load the data

# %%
telecom_customer_churn = pd.read_excel(
    "https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/raw-data/Telco_customer_churn.xlsx"
)

# %%
telecom_customer_churn_demographics = pd.read_excel(
    "https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/raw-data/Telco_customer_churn_demographics.xlsx"
)

# %%
telecom_customer_churn_location = pd.read_excel(
    "https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/raw-data/Telco_customer_churn_location.xlsx"
)

# %%
telecom_customer_churn_population = pd.read_excel(
    "https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/raw-data/Telco_customer_churn_population.xlsx"
)

# %%
telecom_customer_churn_services = pd.read_excel(
    "https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/raw-data/Telco_customer_churn_services.xlsx"
)

# %%
telecom_customer_churn_status = pd.read_excel(
    "https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/raw-data/Telco_customer_churn_status.xlsx"
)

# %% [markdown]
# # 🔵 Check the data

# %% [markdown]
# ### 🟢 Look at the data

# %%
telecom_customer_churn
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
telecom_customer_churn_demographics
# Out:
#      Customer ID  Count  Gender  Age Under 30 Senior Citizen Married  \
# 0     8779-QRDMV      1    Male   78       No            Yes      No
# 1     7495-OOKFY      1  Female   74       No            Yes     Yes
# 2     1658-BYGOY      1    Male   71       No            Yes      No
# 3     4598-XLKNJ      1  Female   78       No            Yes     Yes
# 4     4846-WHAFZ      1  Female   80       No            Yes     Yes
# ...          ...    ...     ...  ...      ...            ...     ...
# 7038  2569-WGERO      1  Female   30       No             No      No
# 7039  6840-RESVB      1    Male   38       No             No     Yes
# 7040  2234-XADUH      1  Female   30       No             No     Yes
# 7041  4801-JZAZL      1  Female   32       No             No     Yes
# 7042  3186-AJIEK      1    Male   44       No             No      No
#
#      Dependents  Number of Dependents
# 0            No                     0
# 1           Yes                     1
# ...

# %%
telecom_customer_churn_location
# Out:
#      Customer ID  Count        Country       State          City  Zip Code  \
# 0     8779-QRDMV      1  United States  California   Los Angeles     90022
# 1     7495-OOKFY      1  United States  California   Los Angeles     90063
# 2     1658-BYGOY      1  United States  California   Los Angeles     90065
# 3     4598-XLKNJ      1  United States  California     Inglewood     90303
# 4     4846-WHAFZ      1  United States  California      Whittier     90602
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude
# ...

# %%
telecom_customer_churn_population
# Out:
#         ID  Zip Code  Population
# 0        1     90001       54492
# 1        2     90002       44586
# 2        3     90003       58198
# 3        4     90004       67852
# 4        5     90005       43019
# ...    ...       ...         ...
# 1666  1667     96145        4002
# 1667  1668     96146         942
# 1668  1669     96148         678
# 1669  1670     96150       33038
# 1670  1671     96161       15783
#
# [1671 rows x 3 columns]

# %%
telecom_customer_churn_services
# Out:
#      Customer ID  Count Quarter Referred a Friend  Number of Referrals  \
# 0     8779-QRDMV      1      Q3                No                    0
# 1     7495-OOKFY      1      Q3               Yes                    1
# 2     1658-BYGOY      1      Q3                No                    0
# 3     4598-XLKNJ      1      Q3               Yes                    1
# 4     4846-WHAFZ      1      Q3               Yes                    1
# ...          ...    ...     ...               ...                  ...
# 7038  2569-WGERO      1      Q3                No                    0
# 7039  6840-RESVB      1      Q3               Yes                    1
# 7040  2234-XADUH      1      Q3               Yes                    4
# 7041  4801-JZAZL      1      Q3               Yes                    1
# 7042  3186-AJIEK      1      Q3                No                    0
#
#       Tenure in Months    Offer Phone Service  \
# 0                    1      NaN            No
# ...

# %%
telecom_customer_churn_status
# Out:
#      Customer ID  Count Quarter  Satisfaction Score Customer Status  \
# 0     8779-QRDMV      1      Q3                   3         Churned
# 1     7495-OOKFY      1      Q3                   3         Churned
# 2     1658-BYGOY      1      Q3                   2         Churned
# 3     4598-XLKNJ      1      Q3                   2         Churned
# 4     4846-WHAFZ      1      Q3                   2         Churned
# ...          ...    ...     ...                 ...             ...
# 7038  2569-WGERO      1      Q3                   5          Stayed
# 7039  6840-RESVB      1      Q3                   3          Stayed
# 7040  2234-XADUH      1      Q3                   4          Stayed
# 7041  4801-JZAZL      1      Q3                   4          Stayed
# 7042  3186-AJIEK      1      Q3                   4          Stayed
#
#      Churn Label  Churn Value  Churn Score  CLTV   Churn Category  \
# 0            Yes            1           91  5433       Competitor
# ...

# %% [markdown]
# ### 🟢 Data columns

# %%
telecom_customer_churn.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
telecom_customer_churn_demographics.columns
# Out:
# Index(['Customer ID', 'Count', 'Gender', 'Age', 'Under 30', 'Senior Citizen',
#        'Married', 'Dependents', 'Number of Dependents'],
#       dtype='object')

# %%
telecom_customer_churn_location.columns
# Out:
# Index(['Customer ID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
telecom_customer_churn_population.columns
# Out:
# Index(['ID', 'Zip Code', 'Population'], dtype='object')

# %%
telecom_customer_churn_services.columns
# Out:
# Index(['Customer ID', 'Count', 'Quarter', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
telecom_customer_churn_status.columns
# Out:
# Index(['Customer ID', 'Count', 'Quarter', 'Satisfaction Score',
#        'Customer Status', 'Churn Label', 'Churn Value', 'Churn Score', 'CLTV',
#        'Churn Category', 'Churn Reason'],
#       dtype='object')

# %% [markdown]
# 🟣 Important and useful columns from "telecom_customer_churn":
# - CustomerID
# - City
# - Latitude
# - Longitude
# - Gender
# - Partner
# - Dependents
# - Tenure Months
# - Phone Service
# - Multiple Lines
# - Internet Service
# - Online Security
# - Online Backup
# - Device Protection
# - Tech Support
# - Streaming TV
# - Streaming Movies
# - Contract
# - Payment Method
# - Monthly Charges
# - Total Charges
# - Churn Label
# - CLTV
#
# 🟣 Important and useful columns from "telecom_customer_churn_services":
# - Customer ID
# - Referred a Friend
# - Number of Referrals
# - Offer
# - Avg Monthly Long Distance Charges
# - Avg Monthly GB Download
# - Premium Tech Support
# - Streaming Music
# - Unlimited Data
# - Total Refunds
# - Total Extra Data Charges
# - Total Long Distance Charges
# - Total Revenue
#
# 🟣 Important and useful columns from "telecom_customer_churn_status":
# - Customer ID
# - Satisfaction Score
# - Customer Status
# - Churn Category
# - Churn Reason
#
# *** difference between "CustomerID" and "Customer ID" in datasets

# %% [markdown]
# # 🔵 Slice the useful data

# %%
telecom_customer_churn_NEW = telecom_customer_churn[["CustomerID",
    "City",
    "Latitude",
    "Longitude",
    "Gender",
    "Partner",
    "Dependents",
    "Tenure Months",
    "Phone Service",
    "Multiple Lines",
    "Internet Service",
    "Online Security",
    "Online Backup",
    "Device Protection",
    "Tech Support",
    "Streaming TV",
    "Streaming Movies",
    "Contract",
    "Payment Method",
    "Monthly Charges",
    "Total Charges",
    "Churn Label",
    "CLTV"
]]

telecom_customer_churn_NEW.rename(columns={"CustomerID": "Customer ID"}, inplace=True)

# %%
telecom_customer_churn_NEW
# Out:
#      Customer ID          City   Latitude   Longitude  Gender Partner  \
# 0     3668-QPYBK   Los Angeles  33.964131 -118.272783    Male      No
# 1     9237-HQITU   Los Angeles  34.059281 -118.307420  Female      No
# 2     9305-CDSKC   Los Angeles  34.048013 -118.293953  Female      No
# 3     7892-POOKP   Los Angeles  34.062125 -118.315709  Female     Yes
# 4     0280-XJGEX   Los Angeles  34.039224 -118.266293    Male      No
# ...          ...           ...        ...         ...     ...     ...
# 7038  2569-WGERO       Landers  34.341737 -116.539416  Female      No
# 7039  6840-RESVB      Adelanto  34.667815 -117.536183    Male     Yes
# 7040  2234-XADUH         Amboy  34.559882 -115.637164  Female     Yes
# 7041  4801-JZAZL  Angelus Oaks  34.167800 -116.864330  Female     Yes
# 7042  3186-AJIEK  Apple Valley  34.424926 -117.184503    Male      No
#
#      Dependents  Tenure Months Phone Service    Multiple Lines  ...  \
# ...

# %%
telecom_customer_churn_services_NEW = telecom_customer_churn_services[["Customer ID",
    "Referred a Friend",
    "Number of Referrals",
    "Offer",
    "Avg Monthly Long Distance Charges",
    "Avg Monthly GB Download",
    "Premium Tech Support",
    "Streaming Music",
    "Unlimited Data",
    "Total Refunds",
    "Total Extra Data Charges",
    "Total Long Distance Charges",
    "Total Revenue",
]]

# %%
telecom_customer_churn_services_NEW
# Out:
#      Customer ID Referred a Friend  Number of Referrals    Offer  \
# 0     8779-QRDMV                No                    0      NaN
# 1     7495-OOKFY               Yes                    1  Offer E
# 2     1658-BYGOY                No                    0  Offer D
# 3     4598-XLKNJ               Yes                    1  Offer C
# 4     4846-WHAFZ               Yes                    1  Offer C
# ...          ...               ...                  ...      ...
# 7038  2569-WGERO                No                    0      NaN
# 7039  6840-RESVB               Yes                    1  Offer C
# 7040  2234-XADUH               Yes                    4      NaN
# 7041  4801-JZAZL               Yes                    1      NaN
# 7042  3186-AJIEK                No                    0      NaN
#
#       Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# 0                                  0.00                        8
# ...

# %%
telecom_customer_churn_status_NEW = telecom_customer_churn_status[["Customer ID",
    "Satisfaction Score",
    "Customer Status",
    "Churn Category",
    "Churn Reason",
]]

# %%
telecom_customer_churn_status_NEW
# Out:
#      Customer ID  Satisfaction Score Customer Status   Churn Category  \
# 0     8779-QRDMV                   3         Churned       Competitor
# 1     7495-OOKFY                   3         Churned       Competitor
# 2     1658-BYGOY                   2         Churned       Competitor
# 3     4598-XLKNJ                   2         Churned  Dissatisfaction
# 4     4846-WHAFZ                   2         Churned            Price
# ...          ...                 ...             ...              ...
# 7038  2569-WGERO                   5          Stayed              NaN
# 7039  6840-RESVB                   3          Stayed              NaN
# 7040  2234-XADUH                   4          Stayed              NaN
# 7041  4801-JZAZL                   4          Stayed              NaN
# 7042  3186-AJIEK                   4          Stayed              NaN
#
#                       Churn Reason
# 0     Competitor offered more data
# 1     Competitor made better offer
# ...

# %% [markdown]
# # 🔵 Integrate the final raw data

# %%
telecom_customer_churn_FINAL = pd.merge(telecom_customer_churn_NEW, telecom_customer_churn_services_NEW, on="Customer ID").merge(
    telecom_customer_churn_status_NEW)

# %%
telecom_customer_churn_FINAL
# Out:
#      Customer ID          City   Latitude   Longitude  Gender Partner  \
# 0     3668-QPYBK   Los Angeles  33.964131 -118.272783    Male      No
# 1     9237-HQITU   Los Angeles  34.059281 -118.307420  Female      No
# 2     9305-CDSKC   Los Angeles  34.048013 -118.293953  Female      No
# 3     7892-POOKP   Los Angeles  34.062125 -118.315709  Female     Yes
# 4     0280-XJGEX   Los Angeles  34.039224 -118.266293    Male      No
# ...          ...           ...        ...         ...     ...     ...
# 7038  2569-WGERO       Landers  34.341737 -116.539416  Female      No
# 7039  6840-RESVB      Adelanto  34.667815 -117.536183    Male     Yes
# 7040  2234-XADUH         Amboy  34.559882 -115.637164  Female     Yes
# 7041  4801-JZAZL  Angelus Oaks  34.167800 -116.864330  Female     Yes
# 7042  3186-AJIEK  Apple Valley  34.424926 -117.184503    Male      No
#
#      Dependents  Tenure Months Phone Service    Multiple Lines  ...  \
# ...

# %% [markdown]
# # 🔵 Save the final raw data

# %%
with open(file="../data/telecom-customer-churn-v0.csv", mode="w", encoding="utf-8") as file_path:
    telecom_customer_churn_FINAL.to_csv(path_or_buf=file_path, index=False, lineterminator="\n")
