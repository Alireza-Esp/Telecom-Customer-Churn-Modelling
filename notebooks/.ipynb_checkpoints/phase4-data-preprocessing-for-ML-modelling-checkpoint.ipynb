# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Telecom Customer Churn Modelling</h1>
#     <h4 align="center" >Alireza Esmaeilpour</h4>
#     <h6 align="center"><a href="https://alireza-esp.ir/">Website</a></h6>
#     <h6 align="center"><a href="https://github.com/Alireza-Esp">Github</a></h6>
#     <h6 align="center"><a href="https://www.kaggle.com/alirezaesmaeilpour">Kaggle</a></h6>
# </div>

# %% [markdown]
# # 🔵 Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sklearn as sk

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 🔵 Load the data

# %%
data = pd.read_csv("https://github.com/Alireza-Esp/Telecom-Customer-Churn-Modelling/raw/refs/heads/main/data/telecom-customer-churn-v2.csv")

# %%
data
# Out:
#               City   Latitude   Longitude  Gender Partner Dependents  \
# 0      Los Angeles  33.964131 -118.272783    Male      No         No
# 1      Los Angeles  34.059281 -118.307420  Female      No        Yes
# 2      Los Angeles  34.048013 -118.293953  Female      No        Yes
# 3      Los Angeles  34.062125 -118.315709  Female     Yes        Yes
# 4      Los Angeles  34.039224 -118.266293    Male      No        Yes
# ...            ...        ...         ...     ...     ...        ...
# 7027       Landers  34.341737 -116.539416  Female      No         No
# 7028      Adelanto  34.667815 -117.536183    Male     Yes        Yes
# 7029         Amboy  34.559882 -115.637164  Female     Yes        Yes
# 7030  Angelus Oaks  34.167800 -116.864330  Female     Yes        Yes
# 7031  Apple Valley  34.424926 -117.184503    Male      No         No
#
#      Phone Service    Multiple Lines Internet Service Unlimited Data  ...  \
# 0              Yes                No              DSL            Yes  ...
# 1              Yes                No      Fiber optic            Yes  ...
# 2              Yes               Yes      Fiber optic            Yes  ...
# 3              Yes               Yes      Fiber optic            Yes  ...
# 4              Yes               Yes      Fiber optic            Yes  ...
# ...            ...               ...              ...            ...  ...
# 7027           Yes                No               No             No  ...
# 7028           Yes               Yes              DSL            Yes  ...
# 7029           Yes               Yes      Fiber optic            Yes  ...
# 7030            No  No phone service              DSL            Yes  ...
# 7031           Yes                No      Fiber optic            Yes  ...
#
#      Total Extra Data Charges Total Revenue Total Refunds Tenure Months  CLTV  \
# 0                           0        129.09          0.00             2  3239
# 1                           0        169.89          0.00             2  2701
# 2                           0        917.70          0.00             8  5372
# 3                           0       3182.97          0.00            28  5003
# 4                           0       7208.47          0.00            49  5340
# ...                       ...           ...           ...           ...   ...
# 7027                        0       3039.53         19.31            72  5306
# 7028                        0       2807.47         48.23            24  2140
# 7029                        0       9453.04         45.38            72  5560
# 7030                        0        319.21         27.24            11  2793
# 7031                        0       8887.86          0.00            66  5097
#
#      Satisfaction Score Customer Status Churn Label Churn Category  \
# 0                     1         Churned         Yes     Competitor
# 1                     2         Churned         Yes          Other
# 2                     3         Churned         Yes          Other
# 3                     3         Churned         Yes          Other
# 4                     1         Churned         Yes     Competitor
# ...                 ...             ...         ...            ...
# 7027                  5          Stayed          No            NaN
# 7028                  3          Stayed          No            NaN
# 7029                  4          Stayed          No            NaN
# 7030                  4          Stayed          No            NaN
# 7031                  4          Stayed          No            NaN
#
#                        Churn Reason
# 0      Competitor made better offer
# 1                             Moved
# 2                             Moved
# 3                             Moved
# 4     Competitor had better devices
# ...                             ...
# 7027                            NaN
# 7028                            NaN
# 7029                            NaN
# 7030                            NaN
# 7031                            NaN
#
# [7032 rows x 38 columns]

# %% [markdown]
# # 🔵 Preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   City                               7032 non-null   object
#  1   Latitude                           7032 non-null   float64
#  2   Longitude                          7032 non-null   float64
#  3   Gender                             7032 non-null   object
#  4   Partner                            7032 non-null   object
#  5   Dependents                         7032 non-null   object
#  6   Phone Service                      7032 non-null   object
#  7   Multiple Lines                     7032 non-null   object
#  8   Internet Service                   7032 non-null   object
#  9   Unlimited Data                     7032 non-null   object
#  10  Online Security                    7032 non-null   object
#  11  Online Backup                      7032 non-null   object
#  12  Device Protection                  7032 non-null   object
#  13  Tech Support                       7032 non-null   object
#  14  Premium Tech Support               7032 non-null   object
#  15  Streaming TV                       7032 non-null   object
#  16  Streaming Movies                   7032 non-null   object
#  17  Streaming Music                    7032 non-null   object
#  18  Contract                           7032 non-null   object
#  19  Payment Method                     7032 non-null   object
#  20  Offer                              3163 non-null   object
#  21  Referred a Friend                  7032 non-null   object
#  22  Number of Referrals                7032 non-null   int64
#  23  Monthly Charges                    7032 non-null   float64
#  24  Total Charges                      7032 non-null   float64
#  25  Avg Monthly Long Distance Charges  7032 non-null   float64
#  26  Total Long Distance Charges        7032 non-null   float64
#  27  Avg Monthly GB Download            7032 non-null   int64
#  28  Total Extra Data Charges           7032 non-null   int64
#  29  Total Revenue                      7032 non-null   float64
#  30  Total Refunds                      7032 non-null   float64
#  31  Tenure Months                      7032 non-null   int64
#  32  CLTV                               7032 non-null   int64
#  33  Satisfaction Score                 7032 non-null   int64
#  34  Customer Status                    7032 non-null   object
#  35  Churn Label                        7032 non-null   object
#  36  Churn Category                     1869 non-null   object
#  37  Churn Reason                       1869 non-null   object
# dtypes: float64(8), int64(6), object(24)
# memory usage: 2.0+ MB

# %%
corr = data[["Satisfaction Score", "Churn Label"]]
corr["Churn Label"] = corr["Churn Label"].astype(bool)
corr["Churn Label"] = corr["Churn Label"].astype(int)
corr
# Out:
#       Satisfaction Score  Churn Label
# 0                      1            1
# 1                      2            1
# 2                      3            1
# 3                      3            1
# 4                      1            1
# ...                  ...          ...
# 7027                   5            1
# 7028                   3            1
# 7029                   4            1
# 7030                   4            1
# 7031                   4            1
#
# [7032 rows x 2 columns]

# %%
corr = corr.corr()

# %%
plot = px.density_heatmap(data_frame=data, y="Satisfaction Score", x="Churn Label")
plot.show()

# %% [markdown]
# 🟣 Remove unhelpful features...

# %% [markdown]
# * "Offer" column has a lot of NULL values. it's better to drop it...

# %%
data.drop(columns=["Offer"], inplace=True)

# %% [markdown]
# * Our dataset has a column named "Number of Referrals". It naturally indicates that does a custemr referred a friend or no.
#   so the "Referred a Friend" column can be deleted...

# %%
data.drop(columns=["Referred a Friend"], inplace=True)

# %% [markdown]
# * the "CLTV" column should to be removed. cause it determined by the company...

# %%
data.drop(columns=["CLTV"], inplace=True)

# %%
, , "",
